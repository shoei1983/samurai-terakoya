# %%
print(1+2)
# Out:
# 3

# %%
print(45 + 18)
print(30 - 12)
print(15 * 6)
print(30 / 3)
print(45 % 8)
print(type(10 / 1))
# Out:
# 63
# 18
# 90
# 10.0
# 5
# <class 'float'>

# %%
print(45 + 1.8)
print(3 - 1.2)
print(15 * 0.6)
print(3 / 0.3)
print(45 % 0.8)
# Out:
# 46.8
# 1.8
# 9.0
# 10.0
# 0.1999999999999975

# %%
print("今日の天気は" + "晴れ")
print("今日の天気は" "曇り")
# Out:
# 今日の天気は晴れ
# 今日の天気は曇り

# %%
print("降水確率" + str(50) + "％" )
# Out:
# 降水確率50％

# %%
print("晴れ" * 5)
print("晴れ" + "晴れ" + "晴れ" + "晴れ" + "晴れ")
# Out:
# 晴れ晴れ晴れ晴れ晴れ
# 晴れ晴れ晴れ晴れ晴れ

# %%
user_name = "侍太郎"
print(user_name)

user_name = "侍花子"
print(user_name)
# Out:
# 侍太郎
# 侍花子

# %%
# 整数型と浮動小数点型の足し算
number1 = 5
number2 = 2.5
print(number1 + number2)

# 文字列型と文字列型の連結
last_name  = "侍"
first_name = "太郎"
print(last_name + first_name)
# Out:
# 7.5
# 侍太郎

# %%
last_name   = "侍"
first_name  = "太郎"
sister_name = "花子"

# 3つの変数を文字列内に埋め込んで表示
print(f"私の名前は{last_name}{first_name}です。妹の名前は{sister_name}です。")
# Out:
# 私の名前は侍太郎です。妹の名前は花子です。

# %%
ue = 10
sita = 20
takasa = 5

print( str((ue + sita) * takasa / 2) + "cm²")
# Out:
# 75.0cm²

# %%
x = 10
print(x)
# Out:
# 10

# %%
user_names = ["侍田太郎", "侍田一郎","侍田二郎","侍田三郎","侍田四郎",]
# 2番目の要素だけを表示　リスト
print(user_names[1])

# 6番目の要素を追加
user_names.append("侍五郎")
print(user_names)

# 3番目の要素を削除（0始まりのため2を指定）
user_names.pop(2)
print(user_names)
# Out:
# 侍田一郎
# ['侍田太郎', '侍田一郎', '侍田二郎', '侍田三郎', '侍田四郎', '侍五郎']
# ['侍田太郎', '侍田一郎', '侍田三郎', '侍田四郎', '侍五郎']

# %%
country_names = ("日本", "アメリカ", "イギリス", "フランス" )

# 3番目の要素である「イギリス」という文字列だけを取り出す　タプル変更×
print(country_names[2])

# すべての要素を取り出す
print(country_names)
# Out:
# イギリス
# ('日本', 'アメリカ', 'イギリス', 'フランス')

# %%
# 1～10までに含まれる素数のセット（2と5が重複）
prime_numbers = {2, 5, 2, 7, 3, 5, 5 }

# セット全体を表示
print(prime_numbers)
# Out:
# {2, 3, 5, 7}

# %%
# 1～10までに含まれる素数のセット
prime_numbers = {2, 3, 5, 7}

# セット全体を表示
print(prime_numbers)

prime_numbers.add(11) # 11をセットに追加
print(prime_numbers)

prime_numbers.remove(3) # セットから3を削除
print(prime_numbers)
# Out:
# {2, 3, 5, 7}
# {2, 3, 5, 7, 11}
# {2, 5, 7, 11}

# %%
country_names = {"アメリカ", "イギリス", "日本", "フランス",}

# セット全体を表示
print(country_names)

# 「ドイツ」をセットに追加
country_names.add("ドイツ")
print(country_names)

# セットから「イギリス」を削除
country_names.remove("イギリス")
print(country_names)
# Out:
# {'アメリカ', 'イギリス', '日本', 'フランス'}
# {'ドイツ', 'アメリカ', '日本', 'フランス', 'イギリス'}
# {'ドイツ', 'アメリカ', '日本', 'フランス'}

# %%
stationery_prices = {"鉛筆": 70, "ボールペン": 120, "シャープペンシル": 150, "消しゴム": 90}

# ボールペンの価格を取り出して表示
print(stationery_prices["ボールペン"])

# 連想配列全体を取り出して表示
print(stationery_prices)
# Out:
# 120
# {'鉛筆': 70, 'ボールペン': 120, 'シャープペンシル': 150, '消しゴム': 90}

# %%
sports = {1: "サッカー", 2: "野球", 3: "バスケット"}

# キー「2」の値を「バドミントン」に書き換える
sports[2] = "バドミントン"

# キー「4」として「水泳」を追加する
sports[4] = "水泳"

# 連想配列全体を取り出して表示
print(sports)
# Out:
# {1: 'サッカー', 2: 'バドミントン', 3: 'バスケット', 4: '水泳'}

# %%
stationery_prices = {"鉛筆": 70, "ボールペン": 120, "シャープペンシル": 150, "消しゴム": 90}

# 「シャープペンシル」を要素ごと削除
stationery_prices.pop("シャープペンシル")

# 連想配列全体を取り出して表示
print(stationery_prices)
# Out:
# {'鉛筆': 70, 'ボールペン': 120, '消しゴム': 90}

# %%
# 課題7　以下の表の内容でリスト（array）とディクショナリ（dictionary）をそれぞれ作成し、水曜日の天気予報を取り出して出力してください。
array = ["月曜日は晴れです", "火曜日は雨です", "水曜日は晴れです", "木曜日は晴れです", "金曜日は曇りです", "土曜日は曇りのち雨です", "日曜日は雷雨です"]

print(array[2])

dictionary = {"mon": "晴れ", "tue": "雨", "wed": "晴れ", "thu": "晴れ", "fri": "曇り", "sat": "曇りのち雨", "sun": "雷雨"}

print(dictionary["wed"])
# Out:
# 水曜日は晴れです
# 晴れ
